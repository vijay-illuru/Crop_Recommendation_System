# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load processed data
train = pd.read_csv("../data/processed/train.csv")

# Quick overview
print(train.head())
print(train.describe())
print(train.info())

# Distribution of features
train.hist(figsize=(10,8))
plt.show()

# Correlation heatmap
plt.figure(figsize=(8,6))
sns.heatmap(train.corr(), annot=True, cmap="coolwarm")
plt.show()

# Boxplots per feature per crop
features = ['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']
for f in features:
    plt.figure(figsize=(10,4))
    sns.boxplot(x='label', y=f, data=train)
    plt.title(f"{f} distribution per crop")
    plt.show()
# Out:
#      N   P   K  temperature   humidity        ph    rainfall  label
# 0   17  16  14    16.396243  92.181519  6.625539  102.944161     16
# 1   37  79  19    27.543848  69.347863  7.143943   69.408782      2
# 2    7  73  25    27.521856  63.132153  7.288057   45.208411     10
# 3  101  70  48    25.360592  75.031933  6.012697  116.553145      1
# 4    0  17  30    35.474783  47.972305  6.279134   97.790725     12
#                  N            P            K  temperature     humidity  \
# count  1760.000000  1760.000000  1760.000000  1760.000000  1760.000000
# mean     50.686364    53.409659    48.136364    25.579640    71.559997
# std      37.297925    33.228169    51.078128     5.090070    22.024009
# min       0.000000     5.000000     5.000000     8.825675    14.273280
# 25%      20.000000    28.000000    20.000000    22.756264    60.280638
# 50%      37.000000    51.000000    31.000000    25.596201    80.511845
# 75%      85.000000    68.000000    48.000000    28.523840    89.902572
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall        label
# count  1760.000000  1760.000000  1760.000000
# mean      6.475940   102.661255    10.543750
# std       0.773445    54.951994     6.304326
# min       3.504752    20.360011     0.000000
# 25%       5.964518    64.092956     5.000000
# 50%       6.433084    94.304074    10.000000
# 75%       6.927832   122.477114    16.000000
# max       9.935091   298.560117    21.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1760 entries, 0 to 1759
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            1760 non-null   int64
#  1   P            1760 non-null   int64
#  2   K            1760 non-null   int64
#  3   temperature  1760 non-null   float64
#  4   humidity     1760 non-null   float64
#  5   ph           1760 non-null   float64
#  6   rainfall     1760 non-null   float64
#  7   label        1760 non-null   int64
# dtypes: float64(4), int64(4)
# memory usage: 110.1 KB
# None
